# %%
import pandas as pd
import time
import os
import datetime
import ccxt

# %%
exchange = ccxt.okx()

# %%
exchange.fetch_order_book('BTC/USDT')['bids']
# Out:
# [[75775.8, 0.68798115, 0],
#  [75775.7, 0.04675693, 0],
#  [75775.6, 0.02903655, 0],
#  [75775.4, 0.02636869, 0],
#  [75774.0, 0.00131971, 0],
#  [75772.0, 0.0691, 0],
#  [75770.4, 0.0165921, 0],
#  [75770.2, 0.00018579, 0],
#  [75769.3, 0.0857354, 0],
#  [75769.2, 0.03291697, 0],
#  [75768.8, 0.216336, 0],
#  [75768.7, 0.02807871, 0],
#  [75768.6, 0.01837399, 0],
#  [75768.0, 0.06026868, 0],
#  [75766.6, 1e-05, 0],
#  [75766.2, 0.02841099, 0],
#  [75766.1, 0.03641462, 0],
#  [75765.2, 0.02, 0],
#  [75764.8, 0.11070006, 0],
#  [75764.5, 0.369, 0],
#  [75764.1, 0.11127666, 0],
#  [75764.0, 0.0691, 0],
#  [75763.8, 0.00103081, 0],
#  [75763.7, 0.05597151, 0],
#  [75763.4, 0.00079, 0],
#  [75763.3, 0.00392158, 0],
#  [75763.1, 0.01320542, 0],
#  [75763.0, 0.01785046, 0],
#  [75762.8, 1e-05, 0],
#  [75762.3, 0.05192831, 0],
#  [75761.6, 0.04001501, 0],
#  [75761.2, 0.08896811, 0],
#  [75761.0, 0.04675693, 0],
#  [75760.9, 0.15464255, 0],
#  [75760.6, 0.00527979, 0],
#  [75760.4, 0.03933486, 0],
#  [75760.1, 0.04, 0],
#  [75760.0, 0.0561956, 0],
#  [75759.0, 1e-05, 0],
#  [75758.6, 0.0007, 0],
#  [75757.3, 0.00660011, 0],
#  [75757.0, 0.00224133, 0],
#  [75756.8, 0.02222054, 0],
#  [75756.5, 0.373853, 0],
#  [75756.2, 0.15264909, 0],
#  [75756.1, 0.08034736, 0],
#  [75756.0, 0.0691, 0],
#  [75755.2, 1e-05, 0],
#  [75755.1, 0.02637576, 0],
#  [75754.0, 0.00095305, 0],
#  [75753.9, 0.395782, 0],
#  [75753.5, 0.19863011, 0],
#  [75753.4, 0.05840513, 0],
#  [75753.1, 0.13242201, 0],
#  [75753.0, 0.40373875, 0],
#  [75752.1, 0.04655265, 0],
#  [75752.0, 0.0691, 0],
#  [75751.4, 1e-05, 0],
#  [75750.7, 0.04556484, 0],
#  [75749.9, 0.04050036, 0],
#  [75749.0, 0.10879287, 0],
#  [75748.0, 0.0991, 0],
#  [75747.6, 1e-05, 0],
#  [75747.4, 1.2e-05, 0],
#  [75746.4, 1.501e-05, 0],
#  [75745.9, 0.008857, 0],
#  [75745.8, 0.01345966, 0],
#  [75745.6, 0.01714092, 0],
#  [75744.9, 0.88152037, 0],
#  [75744.8, 1.88329373, 0],
#  [75744.0, 0.0691, 0],
#  [75743.8, 1e-05, 0],
#  [75743.2, 0.13242201, 0],
#  [75742.3, 0.19863011, 0],
#  [75742.2, 0.369, 0],
#  [75741.6, 0.28595039, 0],
#  [75741.5, 0.02638048, 0],
#  [75741.2, 0.08156484, 0],
#  [75740.2, 0.03, 0],
#  [75740.1, 0.19298353, 0],
#  [75740.0, 0.06911, 0],
#  [75739.5, 0.46839, 0],
#  [75739.2, 0.56368274, 0],
#  [75738.8, 1.501e-05, 0],
#  [75737.8, 0.29896327, 0],
#  [75737.3, 0.12822767, 0],
#  [75737.1, 0.05695606, 0],
#  [75736.3, 0.00158045, 0],
#  [75736.2, 0.00216016, 0],
#  [75735.9, 0.03966027, 0],
#  [75735.6, 0.0165982, 0],
#  [75735.5, 0.13242201, 0],
#  [75734.4, 3.191e-05, 0],
#  [75734.2, 0.13071272, 0],
#  [75734.1, 0.19863011, 0],
#  [75733.9, 0.14001082, 0],
#  [75733.6, 0.369, 0],
#  [75733.3, 0.00050036, 0],
#  [75732.8, 0.04952701, 0],
#  [75732.5, 1e-05, 0]]

# %%
def crawl_exchanges_datas(exchange_name, symbol, start_time, end_time):
    """
    爬取交易所数据的方法.
    :param exchange_name:  交易所名称.
    :param symbol: 请求的symbol: like BTC/USDT, ETH/USD等。
    :param start_time: like 2018-1-1
    :param end_time: like 2019-1-1
    :return:
    """

    exchange_class = getattr(ccxt, exchange_name)
    exchange = exchange_class()
    print(exchange)

    current_path = os.getcwd()
    file_dir = os.path.join(current_path, exchange_name, symbol.replace('/', ''))

    if not os.path.exists(file_dir):
        os.makedirs(file_dir)


    start_time = datetime.datetime.strptime(start_time, '%Y-%m-%d')
    end_time = datetime.datetime.strptime(end_time, '%Y-%m-%d')

    start_time_stamp = int(time.mktime(start_time.timetuple())) * 1000
    end_time_stamp = int(time.mktime(end_time.timetuple())) * 1000

    print(start_time_stamp)  # 1529233920000
    print(end_time_stamp)


    while True:
        try:

            print(start_time_stamp)
            data = exchange.fetch_ohlcv(symbol, timeframe='1m', since=start_time_stamp)
            df = pd.DataFrame(data)
            df.rename(columns={0: 'open_time', 1: 'open', 2: 'high', 3: 'low', 4: 'close', 5: 'volume'}, inplace=True)

            start_time_stamp = int(df.iloc[-1]['open_time'])  # 获取下一个次请求的时间.

            filename = str(start_time_stamp) + '.csv'
            save_file_path = os.path.join(file_dir, filename)

            print("文件保存路径为：%s" % save_file_path)
            df.set_index('open_time', drop=True, inplace=True)
            df.to_csv(save_file_path)

            if start_time_stamp > end_time_stamp:
                print("完成数据的请求.")
                break

            time.sleep(1)

        except Exception as error:
            print(error)
            time.sleep(10)

# %%
crawl_exchanges_datas('okx', 'BTC/USDT', '2024-11-01', '2024-11-05')
# Out:
# OKX
# 1730433600000
# 1730782800000
# 1730433600000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730439540000.csv
# 1730439540000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730445480000.csv
# 1730445480000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730451420000.csv
# 1730451420000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730457360000.csv
# 1730457360000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730463300000.csv
# 1730463300000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730469240000.csv
# 1730469240000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730475180000.csv
# 1730475180000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730481120000.csv
# 1730481120000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730487060000.csv
# 1730487060000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730493000000.csv
# 1730493000000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730498940000.csv
# 1730498940000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730504880000.csv
# 1730504880000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730510820000.csv
# 1730510820000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730516760000.csv
# 1730516760000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730522700000.csv
# 1730522700000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730528640000.csv
# 1730528640000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730534580000.csv
# 1730534580000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730540520000.csv
# 1730540520000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730546460000.csv
# 1730546460000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730552400000.csv
# 1730552400000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730558340000.csv
# 1730558340000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730564280000.csv
# 1730564280000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730570220000.csv
# 1730570220000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730576160000.csv
# 1730576160000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730582100000.csv
# 1730582100000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730588040000.csv
# 1730588040000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730593980000.csv
# 1730593980000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730599920000.csv
# 1730599920000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730605860000.csv
# 1730605860000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730611800000.csv
# 1730611800000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730617740000.csv
# 1730617740000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730623680000.csv
# 1730623680000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730629620000.csv
# 1730629620000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730635560000.csv
# 1730635560000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730641500000.csv
# 1730641500000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730647440000.csv
# 1730647440000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730653380000.csv
# 1730653380000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730659320000.csv
# 1730659320000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730665260000.csv
# 1730665260000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730671200000.csv
# 1730671200000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730677140000.csv
# 1730677140000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730683080000.csv
# 1730683080000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730689020000.csv
# 1730689020000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730694960000.csv
# 1730694960000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730700900000.csv
# 1730700900000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730706840000.csv
# 1730706840000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730712780000.csv
# 1730712780000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730718720000.csv
# 1730718720000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730724660000.csv
# 1730724660000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730730600000.csv
# 1730730600000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730736540000.csv
# 1730736540000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730742480000.csv
# 1730742480000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730748420000.csv
# 1730748420000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730754360000.csv
# 1730754360000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730760300000.csv
# 1730760300000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730766240000.csv
# 1730766240000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730772180000.csv
# 1730772180000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730778120000.csv
# 1730778120000
# 文件保存路径为：c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT\1730784060000.csv
# 完成数据的请求.

# %%
def sample_datas(exchange_name, symbol):
    """

    :param exchange_name:
    :param symbol:
    :return:
    """
    path = os.path.join(os.getcwd(), exchange_name, symbol.replace('/', ''))
    print(path)
    file_paths = []
    for root, dirs, files in os.walk(path):
        if files:
            for file in files:
                if file.endswith('.csv'):
                    file_paths.append(os.path.join(path, file))

    file_paths = sorted(file_paths)
    df_lst = []

    for file in file_paths:
        df_lst.append(pd.read_csv(file))
    all_df = pd.concat(df_lst, axis=0)

    all_df = all_df.sort_values(by='open_time', ascending=True)

    #print(all_df)

    return all_df


def clear_datas(exchange_name, symbol):
    df = sample_datas(exchange_name, symbol)
    df['open_time'] = df['open_time'].apply(lambda x: (x//60)*60)
    # transform to NY time
    df['Datetime'] = pd.to_datetime(df['open_time'], unit='ms') - pd.Timedelta(hours=5)
    df.drop_duplicates(subset=['open_time'], inplace=True)
    df.set_index('Datetime', inplace=True)
    symbol_path = symbol.replace('/', '')
    df.to_csv(f'{exchange_name}_{symbol_path}_1min_data.csv')

# %%
clear_datas('okx','BTC/USDT')
# Out:
# c:\Users\28217\Desktop\crypto_quant\okx\BTCUSDT
#         open_time     open     high      low    close    volume
# 0   1730433600000  69364.1  69370.0  69338.0  69347.2  1.511956
# 1   1730433660000  69349.4  69362.6  69349.4  69352.0  1.597921
# 2   1730433720000  69352.1  69359.2  69340.0  69346.0  0.395598
# 3   1730433780000  69346.3  69369.9  69346.3  69350.0  2.374497
# 4   1730433840000  69350.0  69370.8  69350.0  69360.9  3.079988
# ..            ...      ...      ...      ...      ...       ...
# 95  1730792640000  68903.0  68934.9  68903.0  68919.0  1.545942
# 96  1730792700000  68919.9  68937.9  68900.0  68937.9  2.638381
# 97  1730792760000  68937.9  68974.8  68908.0  68912.5  4.529232
# 98  1730792820000  68912.5  68937.2  68877.3  68928.1  2.036937
# 99  1730792880000  68928.1  68965.1  68902.0  68916.1  2.999849
#
# [7100 rows x 6 columns]
# ********************
#                          open_time     open     high      low    close    volume
# Datetime
# 2024-10-31 23:00:00  1730433600000  69364.1  69370.0  69338.0  69347.2  1.511956
# 2024-10-31 23:01:00  1730433660000  69349.4  69362.6  69349.4  69352.0  1.597921
# 2024-10-31 23:02:00  1730433720000  69352.1  69359.2  69340.0  69346.0  0.395598
# 2024-10-31 23:03:00  1730433780000  69346.3  69369.9  69346.3  69350.0  2.374497
# 2024-10-31 23:04:00  1730433840000  69350.0  69370.8  69350.0  69360.9  3.079988
# ...                            ...      ...      ...      ...      ...       ...
# 2024-11-05 02:44:00  1730792640000  68903.0  68934.9  68903.0  68919.0  1.545942
# 2024-11-05 02:45:00  1730792700000  68919.9  68937.9  68900.0  68937.9  2.638381
# 2024-11-05 02:46:00  1730792760000  68937.9  68974.8  68908.0  68912.5  4.529232
# 2024-11-05 02:47:00  1730792820000  68912.5  68937.2  68877.3  68928.1  2.036937
# 2024-11-05 02:48:00  1730792880000  68928.1  68965.1  68902.0  68916.1  2.999849
#
# [5942 rows x 6 columns]
