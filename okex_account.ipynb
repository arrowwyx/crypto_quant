# %%
import ccxt

# %%
exchange = ccxt.okx({
    'apiKey': '5795f62b-19c5-4749-b0a0-0f6740c7c5a5',
    'secret': '49694A5D375E01505E908B198CD8AA34',
    'password': 'Momo20020703!',
    'timeout': 30000,
    'enableRateLimit': True,
})

# %%
exchange.fetch_balance()['BTC']
# Out:
# {'free': 0.00018839916, 'used': 0.0, 'total': 0.00018839916}

# %%
orderbook = exchange.fetch_order_book(symbol="BTC/USDT", limit=10)

# %%
orderbook
# Out:
# {'symbol': 'BTC/USDT',
#  'bids': [[81592.0, 0.48718964, 0],
#   [81590.7, 0.00018412, 0],
#   [81589.9, 0.12290449, 0],
#   [81589.8, 0.213946, 0],
#   [81589.3, 0.0036955, 0],
#   [81588.9, 0.05641194, 0],
#   [81588.0, 0.0864, 0],
#   [81586.9, 0.01732742, 0],
#   [81586.5, 0.00167944, 0],
#   [81585.8, 0.01, 0]],
#  'asks': [[81592.1, 1.19081024, 0],
#   [81594.8, 0.03415583, 0],
#   [81595.9, 0.01664368, 0],
#   [81596.0, 0.0864, 0],
#   [81597.7, 0.0274702, 0],
#   [81597.8, 0.01821858, 0],
#   [81599.1, 0.08606252, 0],
#   [81599.2, 0.13584, 0],
#   [81600.0, 0.08646141, 0],
#   [81600.2, 0.02781701, 0]],
#  'timestamp': 1731298469400,
#  'datetime': '2024-11-11T04:14:29.400Z',
#  'nonce': None}
